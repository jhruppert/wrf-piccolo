# %%
# Dask test

import numpy as np
import xarray as xr
from dask.distributed import Client

# %%
client = Client(n_workers=2, threads_per_worker=2)#, memory_limit='1GB')
client
# Out:
# /glade/work/ruppert/conda-envs/plotting/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41433 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:42343' processes=2 threads=4, memory=503.17 GiB>

# %%
# Out:
# 1
